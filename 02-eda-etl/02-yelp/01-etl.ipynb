# %%
import numpy as np
import pandas as pd
from pyarrow import json
import pyarrow.parquet as pq
import pickle

# %% [markdown]
# #### Extracion de data y cambio de formato

# %% [markdown]
# ##### Reviews

# %%
table = json.read_json("../../data/Yelp/review-002.json")
pq.write_table(
    table, "../../data/Yelp/data_parquet/review.parquet"
)  # save json/table as parquet

# %%
# Especificamos el tamaño del trozo que queremos leer y guardar
chunksize = 1000000  # 1 millón de filas por trozo

# Abre el archivo Parquet
parquet_file = pq.ParquetFile("../datos_primer_limpieza/review.parquet")

# Obtén el número total de grupos de filas en el archivo Parquet
total_row_groups = parquet_file.num_row_groups

# Itera sobre el archivo Parquet y guarda cada trozo como un archivo CSV
for i in range(0, total_row_groups):
    # Lee un trozo del archivo Parquet
    chunk = parquet_file.read_row_group(i, use_pandas_metadata=True).to_pandas()

    # Guarda el trozo como un archivo CSV
    chunk.to_parquet(
        f"../datos_primer_limpieza/review_chuncks/chunk_review_{i}.parquet", index=False
    )

    # mensaje de procesos completados por archivo
    print(f"Trozo {i + 1} guardado como chunk_review_{i}.parquet")

print("Proceso completo.")
# Out:
# Trozo 1 guardado como chunk_review_0.csv
# Trozo 2 guardado como chunk_review_1.csv
# Trozo 3 guardado como chunk_review_2.csv
# Trozo 4 guardado como chunk_review_3.csv
# Trozo 5 guardado como chunk_review_4.csv
# Trozo 6 guardado como chunk_review_5.csv
# Trozo 7 guardado como chunk_review_6.csv
# Proceso completo.

# %% [markdown]
# ##### Business

# %%
file_name = "../../data/Yelp/business.pkl"
df_business = pd.read_pickle(file_name)

df_business = df_business.iloc[
    :, :14
]  # se le quita las ultimas columnas por que son duplicados vacios de las primeras

df_business.to_parquet("../../data/Yelp/data_parquet/business.parquet")
df_business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %% [markdown]
# ##### Checkin

# %%
df_checkin = pd.read_json("../../data/Yelp/checkin.json", lines=True)

df_checkin.to_parquet(
    "../../data/Yelp/data_parquet/checkin.parquet.gz", compression="gzip"
)

df_checkin
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 2       --30_8IhuyMHbSOcNWd6DQ
# 3       --7PUidqRWpRSpXebiyxTg
# 4       --7jw19RH9JKXgFohspgQw
# ...                        ...
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131928  zzw66H6hVjXQEt0Js3Mo4A
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                      date
# 0       2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1       2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2                2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3       2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4       2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
# ...                                                   ...
# 131925  2013-03-23 16:22:47, 2013-04-07 02:03:12, 2013...
# 131926                                2021-06-12 01:16:12
# ...

# %% [markdown]
# ##### Tip

# %%
df_tip = pd.read_json("../../data/Yelp/tip.json", lines=True)

df_tip.to_parquet("../../data/Yelp/data_parquet/tip.parquet")
df_tip
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text                date  \
# 0                          Avengers time with the ladies. 2012-05-18 02:17:21
# 1       They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# ...

# %% [markdown]
# ##### User

# %%
df_user = pd.read_parquet("../../data/Yelp/user-001.parquet")

df_user.to_parquet("../../data/Yelp/data_parquet/user.parquet")
df_user
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...
